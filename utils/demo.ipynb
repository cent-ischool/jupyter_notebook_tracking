# %%
print("hi")
# Out:
# hi

# %%
import os

# %%
os.environ["JUPYTERHUB_USER"] = "tony@syr.edu"
print(os.environ.get("JUPYTERHUB_USER",""))
# Out:
# tony@syr.edu

# %%
sdhagfjkhasd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 sdhagfjkhasd
#
# NameError: name 'sdhagfjkhasd' is not defined
